# %% [markdown]
# # ProblemStatement:
#
# Perform the following operations using Python on the Facebook metrics data sets
#
#
# a. Create data subsets
#
# b. Merge Data
#
# c. Sort Data
#
# d. Transposing Data
#
# e. Shape and reshape Data

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("dataset_Facebook.csv",delimiter=";")

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df["like"].describe()
# Out:
# count     499.000000
# mean      177.945892
# std       323.398742
# min         0.000000
# 25%        56.500000
# 50%       101.000000
# 75%       187.500000
# max      5172.000000
# Name: like, dtype: float64

# %%
df["Type"].value_counts()
# Out:
# Photo     426
# Status     45
# Link       22
# Video       7
# Name: Type, dtype: int64

# %%
df["Paid"].value_counts()
# Out:
# 0.0    360
# 1.0    139
# Name: Paid, dtype: int64

# %% [markdown]
# ### a) Subset Of Dataset

# %%
sub1=df[['Type','Category','Post Month','Post Weekday']].loc[0:15]

# %%
sub1
# Out:
#       Type  Category  Post Month  Post Weekday
# 0    Photo         2          12             4
# 1   Status         2          12             3
# 2    Photo         3          12             3
# 3    Photo         2          12             2
# 4    Photo         2          12             2
# 5   Status         2          12             1
# 6    Photo         3          12             1
# 7    Photo         3          12             7
# 8   Status         2          12             7
# 9    Photo         3          12             6
# 10  Status         2          12             5
# 11   Photo         2          12             5
# 12   Photo         2          12             5
# 13   Photo         2          12             5
# 14   Photo         2          12             4
# 15  Status         2          12             3

# %%
sub2=df.loc[0:100]

# %%
sub2.shape
# Out:
# (101, 19)

# %%
sub3=df.loc[101:300]

# %%
sub3.shape
# Out:
# (200, 19)

# %%
sub4=df.loc[0:10,['Type','Post Month']]
sub4
# Out:
#       Type  Post Month
# 0    Photo          12
# 1   Status          12
# 2    Photo          12
# 3    Photo          12
# 4    Photo          12
# 5   Status          12
# 6    Photo          12
# 7    Photo          12
# 8   Status          12
# 9    Photo          12
# 10  Status          12

# %%
sub4.shape
# Out:
# (11, 2)

# %% [markdown]
# ### b)Merging of Dataset

# %% [markdown]
# ##### Merge Subset by row

# %%
merge=pd.concat([sub2,sub3])
merge.shape
# Out:
# (301, 19)

# %% [markdown]
# ##### Merge subset by columns

# %%
s1=sub2
s1.shape
# Out:
# (101, 19)

# %%
s2=sub3
s2.shape
# Out:
# (200, 19)

# %%
merge2=s1.merge(s2,on='Type')
merge2.shape
# Out:
# (12997, 37)

# %%
st1=df[['Post Month','Type']]
st1.shape
# Out:
# (500, 2)

# %%
st2=df[['Category','Type']]
st2.shape
# Out:
# (500, 2)

# %%
merge3=st1.merge(st2,left_index=True,right_index=True)
merge3
# Out:
#      Post Month  Type_x  Category  Type_y
# 0            12   Photo         2   Photo
# 1            12  Status         2  Status
# 2            12   Photo         3   Photo
# 3            12   Photo         2   Photo
# 4            12   Photo         2   Photo
# ..          ...     ...       ...     ...
# 495           1   Photo         3   Photo
# 496           1   Photo         2   Photo
# 497           1   Photo         1   Photo
# 498           1   Photo         3   Photo
# 499           1   Photo         2   Photo
#
# [500 rows x 4 columns]

# %% [markdown]
# ### c)Sorting Values

# %%
sort=df.sort_values('Page total likes',ascending=False)

# %%
sort
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 8              139441  Status         2          12             7          3
# 1              139441  Status         2          12             3         10
# 12             139441   Photo         2          12             5         10
# 11             139441   Photo         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
sort1=df.sort_values(by='Type')
sort1
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 438             98195   Link         2           3             6          6
# 470             91437   Link         1           2             3         13
# 41             138895   Link         1          12             6          3
# 43             138353   Link         1          12             5          3
# 45             138353   Link         1          12             4          3
# ..                ...    ...       ...         ...           ...        ...
# 71             137893  Video         1          11             5          3
# 55             138329  Video         1          11             6          2
# 277            126424  Video         1           6             2         13
# 243            130791  Video         1           7             3         11
# 74             137893  Video         1          11             3         11
#
# ...

# %% [markdown]
# ##### Sort the Dataframe based on multiple columns

# %%
sort2=df.sort_values(by=['Type','Post Month','Paid'])
sort2
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 477             86909   Link         1           1             6          4
# 485             86491   Link         1           1             2          2
# 492             85979   Link         1           1             5         11
# 481             86491   Link         1           1             4          4
# 470             91437   Link         1           2             3         13
# ..                ...    ...       ...         ...           ...        ...
# 183            134879  Video         1           9             2         10
# 74             137893  Video         1          11             3         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 29             138895  Video         1          12             4         11
#
# ...

# %% [markdown]
# ### d)Transposing Data

# %%
Tp=df.transpose()
Tp.shape
# Out:
# (19, 500)

# %%
Tp
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %% [markdown]
# ### e)Shape and Reshape Data

# %%
shaping=df.shape

# %%
shaping
# Out:
# (500, 19)

# %%
reshaping=pd.pivot_table(df,index=['Type','Category'],values='comment')

# %%
print(reshaping)
# Out:
#                    comment
# Type   Category
# Link   1          2.900000
#        2          2.000000
#        3          2.000000
# Photo  1          5.897297
#        2         11.692308
#        3          6.913333
# Status 1          4.333333
#        2          9.921053
#        3          2.750000
# Video  1         12.285714

# %%
res=pd.melt(df,id_vars=['Type'],value_vars=['Post Month','Category'])

# %%
res
# Out:
#        Type    variable  value
# 0     Photo  Post Month     12
# 1    Status  Post Month     12
# 2     Photo  Post Month     12
# 3     Photo  Post Month     12
# 4     Photo  Post Month     12
# ..      ...         ...    ...
# 995   Photo    Category      3
# 996   Photo    Category      2
# 997   Photo    Category      1
# 998   Photo    Category      3
# 999   Photo    Category      2
#
# [1000 rows x 3 columns]
